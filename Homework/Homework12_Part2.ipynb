# %% [markdown]
# # CS530 Homework 12 Part 2

# %% [markdown]
# #### Question 1 (3 points)
#
# Complete the in-class group work that we started on Monday (April 26, 2021) **with the group with whom you worked in class**. Only one person needs to submit a colab link. But make sure to include the names of all the people in your group in your submission.

# %% [markdown]
# Group Members: Toby Chappell, Noah Ferrel, Raha Pirzadeh
# https://colab.research.google.com/drive/17J3Opck_Nw5Mkp_kkA58y7yNAVFW4AJM?usp=sharing

# %% [markdown]
# #### Question 2 (3 points)
#
# **Complete this question on your own and submit it individually.**
#
#
# We would like you to gain some familiarity with Keras, a powerful deep-learning package to design various neural-network architectures in python.
#
# For the following task you should import the MNIST dataset and create a small 4 layer neural network that will classify the 10 digits in the dataset (remember to test on a different dataset from which you trained).
#
# When working through this problem think practically about what you know about neural networks. When building your network you should generally strive for maximal accuracy. You can even compare your accuracy with the best ones achieved on MNIST (see #MNIST at the bottom). But first think about and answer the following questions:
#   - How many input neurons do you need to feed in your data to the NN?
#   - How many nodes does it make sense to put in each of the hidden layers? Think about the trade off between the accuracy on the one hand and the computational expense and the number of parameters that you must train to train a larger network on the other hand. You should also try it out.
#   - How many output neurons do you need?
#   - What type of activation function should you use to get the correct output?
#   - What would happen if you decrease the number of layers to 3 or increase it to 5? Try it out. Does it make sense to decrease the number of layers to 2? Explain your answer.
#
# Your focus should be on getting your data into the correct format, building your network, and reading the documentation. But keep an eye on your accuracy.
#
# Add different layers/neurons and really play with the network (build it, break it!) then tell us about some intuition you gained from changing these parameters (100 words max).
#
# Note: Keras uses TensorFlow (tf) on the backend. So, if you are using code with "tf" in some of the commands, you are still on the right track.
#
#
# https://keras.io/getting_started/intro_to_keras_for_researchers/  # Keras documentation
#
# https://www.tensorflow.org/guide/keras/sequential_model           # Keras documentation from Tensorflow
#
# https://en.wikipedia.org/wiki/MNIST_database                      # MNIST

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import SGD
import warnings

# %%
batch_size = 128
epochs = 5

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=SGD())
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test))
loss_and_metrics = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss", loss_and_metrics[0])
print("Test Accuracy", loss_and_metrics[1])
# Out:
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.6207 - accuracy: 0.5636 - val_loss: 0.8056 - val_accuracy: 0.8291
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7621 - accuracy: 0.8349 - val_loss: 0.6049 - val_accuracy: 0.8621
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6032 - accuracy: 0.8593 - val_loss: 0.5245 - val_accuracy: 0.8735
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5298 - accuracy: 0.8678 - val_loss: 0.4791 - val_accuracy: 0.8815
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4952 - accuracy: 0.8743 - val_loss: 0.4492 - val_accuracy: 0.8863
# Test Loss 0.4492386281490326
# Test Accuracy 0.8863000273704529

# %%
model = Sequential()
model.add(Dense(397, activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=SGD())
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test))
loss_and_metrics = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss", loss_and_metrics[0])
print("Test Accuracy", loss_and_metrics[1])
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 1.5546 - accuracy: 0.5679 - val_loss: 0.6119 - val_accuracy: 0.8629
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.6127 - accuracy: 0.8458 - val_loss: 0.4414 - val_accuracy: 0.8882
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4730 - accuracy: 0.8732 - val_loss: 0.3779 - val_accuracy: 0.9009
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4223 - accuracy: 0.8834 - val_loss: 0.3446 - val_accuracy: 0.9071
# Epoch 5/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3866 - accuracy: 0.8920 - val_loss: 0.3214 - val_accuracy: 0.9127
# Test Loss 0.32144027948379517
# Test Accuracy 0.9126999974250793

# %%
model = Sequential()
model.add(Dense(397, activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(397,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=SGD())
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test))
loss_and_metrics = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss", loss_and_metrics[0])
print("Test Accuracy", loss_and_metrics[1])
# Out:
# Epoch 1/5
# 469/469 [==============================] - 7s 13ms/step - loss: 1.7366 - accuracy: 0.4792 - val_loss: 0.5811 - val_accuracy: 0.8609
# Epoch 2/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.6228 - accuracy: 0.8243 - val_loss: 0.3967 - val_accuracy: 0.8953
# Epoch 3/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.4636 - accuracy: 0.8652 - val_loss: 0.3371 - val_accuracy: 0.9063
# Epoch 4/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.4047 - accuracy: 0.8840 - val_loss: 0.3071 - val_accuracy: 0.9149
# Epoch 5/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3699 - accuracy: 0.8915 - val_loss: 0.2845 - val_accuracy: 0.9191
# Test Loss 0.28448769450187683
# Test Accuracy 0.9190999865531921

# %%
model = Sequential()
model.add(Dense(397, activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(397,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(397,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=SGD())
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test))
loss_and_metrics = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss", loss_and_metrics[0])
print("Test Accuracy", loss_and_metrics[1])
# Out:
# Epoch 1/5
# 469/469 [==============================] - 9s 18ms/step - loss: 1.9146 - accuracy: 0.3911 - val_loss: 0.5661 - val_accuracy: 0.8550
# Epoch 2/5
# 469/469 [==============================] - 8s 17ms/step - loss: 0.6559 - accuracy: 0.8032 - val_loss: 0.3744 - val_accuracy: 0.8960
# Epoch 3/5
# 469/469 [==============================] - 8s 17ms/step - loss: 0.4824 - accuracy: 0.8557 - val_loss: 0.3131 - val_accuracy: 0.9099
# Epoch 4/5
# 469/469 [==============================] - 8s 18ms/step - loss: 0.4035 - accuracy: 0.8818 - val_loss: 0.2817 - val_accuracy: 0.9176
# Epoch 5/5
# 469/469 [==============================] - 8s 18ms/step - loss: 0.3632 - accuracy: 0.8923 - val_loss: 0.2555 - val_accuracy: 0.9243
# Test Loss 0.2555411458015442
# Test Accuracy 0.9243000149726868

# %%
model = Sequential()
model.add(Dense(529, activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(264,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=SGD())
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test))
loss_and_metrics = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss", loss_and_metrics[0])
print("Test Accuracy", loss_and_metrics[1])
# Out:
# Epoch 1/5
# 469/469 [==============================] - 7s 14ms/step - loss: 1.6649 - accuracy: 0.5191 - val_loss: 0.5332 - val_accuracy: 0.8688
# Epoch 2/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.5880 - accuracy: 0.8324 - val_loss: 0.3747 - val_accuracy: 0.8996
# Epoch 3/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.4485 - accuracy: 0.8710 - val_loss: 0.3240 - val_accuracy: 0.9106
# Epoch 4/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3981 - accuracy: 0.8835 - val_loss: 0.2950 - val_accuracy: 0.9167
# Epoch 5/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3577 - accuracy: 0.8958 - val_loss: 0.2739 - val_accuracy: 0.9226
# Test Loss 0.273904412984848
# Test Accuracy 0.9225999712944031

# %%
model = Sequential()
model.add(Dense(595, activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(397,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(198,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=SGD())
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test))
loss_and_metrics = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss", loss_and_metrics[0])
print("Test Accuracy", loss_and_metrics[1])
# Out:
# Epoch 1/5
# 469/469 [==============================] - 10s 20ms/step - loss: 1.8473 - accuracy: 0.4104 - val_loss: 0.5365 - val_accuracy: 0.8589
# Epoch 2/5
# 469/469 [==============================] - 9s 19ms/step - loss: 0.6338 - accuracy: 0.8082 - val_loss: 0.3620 - val_accuracy: 0.8951
# Epoch 3/5
# 469/469 [==============================] - 9s 20ms/step - loss: 0.4610 - accuracy: 0.8635 - val_loss: 0.3017 - val_accuracy: 0.9124
# Epoch 4/5
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3972 - accuracy: 0.8812 - val_loss: 0.2689 - val_accuracy: 0.9213
# Epoch 5/5
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3501 - accuracy: 0.8973 - val_loss: 0.2461 - val_accuracy: 0.9275
# Test Loss 0.2460753619670868
# Test Accuracy 0.9275000095367432

# %% [markdown]
#   - How many input neurons do you need to feed in your data to the NN?
#
#   784 neurons (one for each pixel)
#
#   - How many nodes does it make sense to put in each of the hidden layers? Think about the trade off between the accuracy on the one hand and the computational expense and the number of parameters that you must train to train a larger network on the other hand. You should also try it out.
#
#   The number of nodes should range between 10 and 784. It would also make sense to use less nodes when advancing to the next layer (there is a large gap between 10 qnd 784 so we need to bridge that gap in a sense). It should be noted that more nodes would mean higher computational cost while less nodes would correlate with worse accuracy.
#
#   - How many output neurons do you need?
#
#   10 neurons (one for each digit)
#
#   - What type of activation function should you use to get the correct output?
#
#   We need a softmax activation function for the last layer in order to predict our multi-class targets and relu for the rest of the hidden layers.
#
#   - What would happen if you decrease the number of layers to 3 or increase it to 5? Try it out. Does it make sense to decrease the number of layers to 2? Explain your answer.
#
#   Decreasing the number of layers will allow the NN to be computationally cheaper at the expense of accuracy. Conversely, increasing the number of layers will make the model more accurate but it will perform much slower. Using only 2 layers in this case can actually obtain fairly high accuracy (88%), but the accuracy from using 5 layers is much more substantial (93%). However, if speed is a priority using 2 layers could make sense given that it's accuracy is still high.

# %% [markdown]
# *NN Intuition*

# %% [markdown]
# From this exercise, it is quite clear that increasing the number of nodes or the number of hidden layers can increase the computational cost by quite a bit. Furthermore, while adding more layers can increase the accuracy of a model, the boost in accuracy lessens as the number of layers increases. From experimenting with different models, by decreasing the number of nodes each time the model was able to obtain a slightly higher accuracy (about 1% more relative to the number of layers). The reason for this is most likely that it helped bridge the gap between inputs and outputs for this particular dataset.

# %% [markdown]
# #### Question 3 (4 points)
#
# **Complete question 3 in your final-project group.**  Only one person needs to submit the answers to the following by providing a colab link with the following code snipets/information. Make sure to include the names of all the people in your group with your submission.
#
# During the past few weeks, you have grown your final project significantly and should have substantial work done for your main analysis with some preliminary results.
#
# Submit the following components:
#
# * Colab for your main analysis
#     - Remember to adhere to good documentation practices.
# * Visualization of your main analysis results
#     - Be thoughtful about this visualization and what you have previously submitted since your project and paper should create the narrative of all the work you have done.
#
# * A draft of your methods for your final project describing the analysis from above
#     - This was described in the last homework. (250 words max for this draft)
# * From your preliminary results, what have you learned from your data/problem?  Did you come across any unexpected results or challenges?  (100 words max)
#
# * Based on what you have learned so far, does a NN make sense for your project?  Explain why you would or would not use a NN. (100 words max)

# %% [markdown]
# Colab Notebook: https://colab.research.google.com/drive/1gMENUbUVgwKUP0vke4RLxUHL2TrOXa64?usp=sharing
#
# Google Doc: https://docs.google.com/document/d/1Cs6r4s0NoQNgLd6vUU2La4H5vu6-zGp0XLFflO9oX_Q/edit
